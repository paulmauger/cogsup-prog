# %% [markdown]
# # Introduction to `tidyverse` Round 2
# An ["opinionated" collection of R packages](https://tidyverse.org) for data science, driven by a coherent underlying design philosophy.
# These packages are meant to help you with two essential processes:
# 1. **Data clean-up and organization**: Structure should be intuitive, so that it's easy to model, manipulate, and think about the data
# 2. **Data plotting**: The grammar of graphics (Week 13)

# %%
library(tidyverse)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Loading the data

# %%
data <- read_csv("data/148338_220209_095045_M057814.csv", skip=2)
# Out:
# Rows: 241 Columns: 32
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (21): type, stim1, stim2, stimPos, stimFormat, feedbackIncorrect, head, ...
# dbl (11): rowNo, ITI, feedbackTime, random, ITI_ms, ITI_f, ITI_fDuration, ti...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
education_level <- data %>% pull(response) %>% first()  

data <- data %>%
    # Keep only useful columns
    select(c(rowNo, type, stim1, stim2, stimPos, trialType, response, RT)) %>%
    
    # Keep only useful rows
    filter(type != "form") %>%
    
    # Add demographic and trial-number info, turn trial type to factor
    mutate(
        education_level = education_level, # Add info
        trial_number = row_number(),
        trialType = factor(trialType, levels = c("incongruent", "congruent"))
    ) %>%
    
    # Rename trialType to trial_type
    rename(trial_type = trialType)

head(data)
# Out:
#   rowNo type stim1          stim2          stimPos       trial_type  response
# 1 190   test croissantLarge breadSmall     -341 0; 341 0 incongruent j
# 2 125   test lampSmall      shelfLarge     -235 0; 235 0 congruent   f
# 3 200   test schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j
# 4 152   test orangeLarge    raspberrySmall -307 0; 307 0 congruent   j
# 5 110   test hammerLarge    ladderSmall    -156 0; 156 0 incongruent j
# 6 215   test wheelSmall     coinLarge      -300 0; 300 0 incongruent f
#   RT   education_level             trial_number
# 1  729 College or Technical School 1
# 2  625 College or Technical School 2
# 3 1477 College or Technical School 3
# 4  793 College or Technical School 4
# 5  900 College or Technical School 5
# 6  699 College or Technical School 6

# %% [markdown]
# ### Tidying the data

# %% [markdown]
# Our data is almost tidy, but we still need to do several things.

# %% [markdown]
# #### Exercise 1
# There are two columns that are uninformative. Remove them.

# %%
data <- data %>% select(-type, -education_level)
# Out:
# Error in `select()`:
# ! Can't select columns that don't exist.
# ✖ Column `feedbackIncorrect` doesn't exist.
# Traceback:
#
# 1. select(., -feedbackIncorrect, -feedbackTime)
# 2. select.data.frame(., -feedbackIncorrect, -feedbackTime)
# 3. tidyselect::eval_select(expr(c(...)), data = .data, error_call = error_call)
# 4. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#  .     error_call = error_call, )
# 5. with_subscript_errors(out <- vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#  .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#  .     type = type, error_call = error_call), type = type)
# 6. withCallingHandlers(expr, vctrs_error_subscript = function(cnd) {
#  .     cnd$subscript_action <- subscript_action(type)
#  .     cnd$subscript_elt <- "column"
#  .     cnd_signal(cnd)
#  . })
# 7. vars_select_eval(vars, expr, strict = strict, data = x, name_spec = name_spec,
#  .     uniquely_named = uniquely_named, allow_rename = allow_rename,
#  .     allow_empty = allow_empty, allow_predicates = allow_predicates,
#  .     type = type, error_call = error_call)
# 8. walk_data_tree(expr, data_mask, context_mask)
# 9. eval_c(expr, data_mask, context_mask)
# 10. reduce_sels(node, data_mask, context_mask, init = init)
# 11. walk_data_tree(new, data_mask, context_mask)
# 12. as_indices_sel_impl(out, vars = vars, strict = strict, data = data,
#   .     allow_predicates = allow_predicates, call = error_call, arg = as_label(expr))
# 13. as_indices_impl(x, vars, call = call, arg = arg, strict = strict)
# 14. chr_as_locations(x, vars, call = call, arg = arg)
# 15. vctrs::vec_as_location(x, n = length(vars), names = vars, call = call,
#   .     arg = arg)
# 16. (function ()
#   . stop_subscript_oob(i = i, subscript_type = subscript_type, names = names,
#   .     subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .     call = call))()
# 17. stop_subscript_oob(i = i, subscript_type = subscript_type, names = names,
#   .     subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .     call = call)
# 18. stop_subscript(class = "vctrs_error_subscript_oob", i = i, subscript_type = subscript_type,
#   .     ..., call = call)
# 19. abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .     call = call)
# 20. signal_abort(cnd, .file)
# 21. signalCondition(cnd)
# 22. (function (cnd)
#   . {
#   .     cnd$subscript_action <- subscript_action(type)
#   .     cnd$subscript_elt <- "column"
#   .     cnd_signal(cnd)
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     withRestarts(with_handlers({
#   .         for (expr in tle$exprs) {
#   .             ev <- withVisible(eval(expr, envir))
#   .             watcher$capture_plot_and_output()
#   .             watcher$print_value(ev$value, ev$visible, envir)
#   .         }
#   .         TRUE
#   .     }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE),
#   .     withRestartList(expr, restarts), withOneRestart(withRestartList(expr,
#   .         restarts[-nr]), restarts[[nr]]), doWithOneRestart(return(expr),
#   .         restart), withRestartList(expr, restarts[-nr]), withOneRestart(expr,
#   .         restarts[[1L]]), doWithOneRestart(return(expr), restart),
#   .     with_handlers({
#   .         for (expr in tle$exprs) {
#   .             ev <- withVisible(eval(expr, envir))
#   .             watcher$capture_plot_and_output()
#   .             watcher$print_value(ev$value, ev$visible, envir)
#   .         }
#   .         TRUE
#   .     }, handlers), eval(call), eval(call), withCallingHandlers(code,
#   .         message = `<fn>`, warning = `<fn>`, error = `<fn>`),
#   .     withVisible(eval(expr, envir)), eval(expr, envir), eval(expr,
#   .         envir), data %>% select(-feedbackIncorrect, -feedbackTime),
#   .     select(., -feedbackIncorrect, -feedbackTime), select.data.frame(.,
#   .         -feedbackIncorrect, -feedbackTime), tidyselect::eval_select(expr(c(...)),
#   .         data = .data, error_call = error_call), eval_select_impl(data,
#   .         names(data), as_quosure(expr, env), include = include,
#   .         exclude = exclude, strict = strict, name_spec = name_spec,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, error_call = error_call,
#   .         ), with_subscript_errors(out <- vars_select_eval(vars,
#   .         expr, strict = strict, data = x, name_spec = name_spec,
#   .         uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .         allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .         type = type, error_call = error_call), type = type),
#   .     withCallingHandlers(expr, vctrs_error_subscript = function(cnd) {
#   .         cnd$subscript_action <- subscript_action(type)
#   .         cnd$subscript_elt <- "column"
#   .         cnd_signal(cnd)
#   .     }), vars_select_eval(vars, expr, strict = strict, data = x,
#   .         name_spec = name_spec, uniquely_named = uniquely_named,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, type = type, error_call = error_call),
#   .     walk_data_tree(expr, data_mask, context_mask), eval_c(expr,
#   .         data_mask, context_mask), reduce_sels(node, data_mask,
#   .         context_mask, init = init), walk_data_tree(new, data_mask,
#   .         context_mask), as_indices_sel_impl(out, vars = vars,
#   .         strict = strict, data = data, allow_predicates = allow_predicates,
#   .         call = error_call, arg = as_label(expr)), as_indices_impl(x,
#   .         vars, call = call, arg = arg, strict = strict), chr_as_locations(x,
#   .         vars, call = call, arg = arg), vctrs::vec_as_location(x,
#   .         n = length(vars), names = vars, call = call, arg = arg),
#   .     `<fn>`(), stop_subscript_oob(i = i, subscript_type = subscript_type,
#   .         names = names, subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .         call = call), stop_subscript(class = "vctrs_error_subscript_oob",
#   .         i = i, subscript_type = subscript_type, ..., call = call),
#   .     abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .         call = call)), parent = c(0L, 1L, 2L, 3L, 4L, 5L, 6L,
#   . 7L, 6L, 9L, 10L, 4L, 12L, 13L, 14L, 15L, 14L, 17L, 18L, 12L,
#   . 20L, 21L, 20L, 12L, 12L, 25L, 0L, 0L, 0L, 29L, 30L, 31L, 32L,
#   . 31L, 34L, 35L, 36L, 37L, 38L, 39L, 40L, 41L, 0L, 43L, 44L, 45L
#   . ), visible = c(TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE), namespace = c("IRkernel",
#   . NA, "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "base", "base", "base", "base", "base", "base",
#   . NA, "dplyr", "dplyr", "tidyselect", "tidyselect", "tidyselect",
#   . "base", "tidyselect", "tidyselect", "tidyselect", "tidyselect",
#   . "tidyselect", "tidyselect", "tidyselect", "tidyselect", "vctrs",
#   . "vctrs", "vctrs", "vctrs", "rlang"), scope = c("::", NA, "local",
#   . NA, "::", "local", "local", "local", "local", "local", "local",
#   . "::", "::", "local", "local", "local", "local", "local", "local",
#   . ":::", "::", "::", "::", "::", "::", "::", NA, "::", ":::", "::",
#   . ":::", ":::", "::", ":::", ":::", ":::", ":::", ":::", ":::",
#   . ":::", ":::", "::", "local", ":::", ":::", "::"), error_frame = c(FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . TRUE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE
#   . )), row.names = c(NA, -46L), version = 2L, class = c("rlang_trace",
#   . "rlib_trace", "tbl", "data.frame")), parent = NULL, i = "feedbackIncorrect",
#   .     subscript_type = "character", names = c("rowNo", "type",
#   .     "stim1", "stim2", "stimPos", "trial_type", "response", "RT",
#   .     "education_level", "trial_number"), subscript_action = NULL,
#   .     subscript_arg = "feedbackIncorrect", rlang = list(inherit = TRUE),
#   .     call = select(., -feedbackIncorrect, -feedbackTime)), class = c("vctrs_error_subscript_oob",
#   . "vctrs_error_subscript", "rlang_error", "error", "condition")))
# 23. cnd_signal(cnd)
# 24. signal_abort(cnd)
# 25. signalCondition(cnd)

# %% [markdown]
# #### Exercise 2
# The columns `stim1` and `stim2` refer to the stimulus presented on the left and, respectively, right. Rename the columns to make them more informative.

# %%
data <- data %>% rename(stim_left = stim1, stim_right = stim2)

# %% [markdown]
# #### Exercise 3
# Add a new column called `subject_id` and set this participant to 1.

# %%
data <- data %>% mutate(subject_id = 1)

# %% [markdown]
# #### Exercise 4
# Add a new column called `correct_side`. This column should encode the side of the correct answer (equivalently, the side of the smaller image). Use `str_detect(string, pattern)` to compute where the smaller image was on the screen and use a conditional `mutate` to fill in the values of `correct_side`.

# %%
data <- data %>% 
  mutate(correct_side = if_else(str_detect(stim_left, "Small"), "left", "right"))

# %% [markdown]
# #### Exercise 5
# Add a new column called `correct_key`. This column should be equal to `f` if the smaller image was on the left, and to `j` if the smaller image was on the right.

# %%
data <- data %>% 
  mutate(correct_key = if_else(correct_side == "left", "f", "j"))

# %% [markdown]
# #### Exercise 6
# Add a new column called `correct`. This column should be equal to 1 if the participant provided a correct response, 0 otherwise.

# %%
data <- data %>% 
  mutate(correct = if_else(response == correct_key, 1, 0))

# %% [markdown]
# #### Exercise 7
# The experiment had 240 trials, equally divided into two blocks. Add a new column called `trial_block` that encodes this.

# %%
data <- data %>% 
  mutate(trial_block = if_else(rowNo <= 120, 1, 2))

# %% [markdown]
# #### Exercise 8
# Recode `trial_number` so that it codes the trial number within a block. Instead of going from 1 to 240, it should go from 1 to 120 twice.

# %%
data <- data %>% 
  mutate(trial_number = if_else(rowNo > 120, rowNo - 120, rowNo))

# %%
data
# Out:
#     rowNo stim_left        stim_right      stimPos       trial_type  response
# 1   190   croissantLarge   breadSmall      -341 0; 341 0 incongruent j
# 2   125   lampSmall        shelfLarge      -235 0; 235 0 congruent   f
# 3   200   schoolbusLarge   bikeSmall       -370 0; 370 0 congruent   j
# 4   152   orangeLarge      raspberrySmall  -307 0; 307 0 congruent   j
# 5   110   hammerLarge      ladderSmall     -156 0; 156 0 incongruent j
# 6   215   wheelSmall       coinLarge       -300 0; 300 0 incongruent f
# 7   139   coconutSmall     blueberryLarge  -309 0; 309 0 incongruent f
# 8   160   pumpkinLarge     mushroomSmall   -304 0; 304 0 congruent   j
# 9   189   croissantSmall   breadLarge      -341 0; 341 0 congruent   f
# 10  114   trayLarge        bedSmall        -350 0; 350 0 incongruent j
# 11  172   lettuceLarge     oliveSmall      -365 0; 365 0 congruent   j
# 12  175   cornSmall        green beanLarge -349 0; 349 0 incongruent f
# 13  165   chilliSmall      eggplantLarge   -274 0; 274 0 congruent   f
# 14   93   kittySmall       donkeyLarge     -309 0; 309 0 congruent   f
# 15  138   apricotLarge     watermelonSmall -300 0; 300 0 incongruent j
# 16   59   cowSmall         hedgehogLarge   -358 0; 358 0 incongruent f
# 17  167   cauliflowerSmall onionLarge      -321 0; 321 0 incongruent f
# 18   49   duckSmall        zebraLarge      -311 0; 311 0 congruent   f
# 19  213   wheelbarrowSmall carLarge        -347 0; 347 0 congruent   f
# 20  128   dishwasherLarge  backpackSmall   -259 0; 259 0 congruent   j
# 21   65   chickenSmall     pandaLarge      -333 0; 333 0 congruent   f
# 22   45   parrotSmall      orangutanLarge  -207 0; 207 0 congruent   f
# 23  204   airplaneLarge    skateboardSmall -334 0; 334 0 congruent   j
# 24   87   deerSmall        frogLarge       -299 0; 299 0 incongruent f
# 25   83   giraffeSmall     antLarge        -324 0; 324 0 incongruent f
# 26   51   dolphinSmall     goldfishLarge   -341 0; 341 0 incongruent f
# 27  116   tableLarge       hairdryerSmall  -350 0; 350 0 congruent   j
# 28   77   beeSmall         sheepLarge      -321 0; 321 0 congruent   f
# 29  229   graterSmall      skyscraperLarge -220 0; 220 0 congruent   f
# 30   91   donkeySmall      kittyLarge      -317 0; 317 0 incongruent f
# ⋮   ⋮     ⋮                ⋮               ⋮             ⋮           ⋮
# 211  43   orangutanSmall   parrotLarge     -198 0; 198 0 incongruent f
# 212  42   pigeonLarge      camelSmall      -250 0; 250 0 incongruent j
# 213  33   squirrelSmall    gorillaLarge    -306 0; 306 0 congruent   f
# 214 143   pineappleSmall   cherryLarge     -223 0; 223 0 incongruent f
# 215 226   lighterLarge     treeSmall       -192 0; 192 0 incongruent j
# 216  20   alligatorLarge   shrimpSmall     -337 0; 337 0 congruent   j
# 217 250   beltLarge        cannonSmall     -353 0; 353 0 incongruent j
# 218 131   ovenSmall        bootLarge       -280 0; 280 0 incongruent f
# 219 174   oliveLarge       lettuceSmall    -363 0; 363 0 incongruent j
# 220 224   treeLarge        lighterSmall    -208 0; 208 0 congruent   j
# 221 248   cannonLarge      beltSmall       -353 0; 353 0 congruent   j
# 222 132   ovenLarge        bootSmall       -273 0; 273 0 congruent   j
# 223  76   sheepLarge       beeSmall        -321 0; 321 0 congruent   j
# 224 129   backpackSmall    dishwasherLarge -259 0; 259 0 congruent   f
# 225 102   scissorsLarge    trunkSmall      -198 0; 198 0 incongruent j
# 226 247   cannonSmall      beltLarge       -353 0; 353 0 incongruent f
# 227 157   plumSmall        melonLarge      -330 0; 330 0 congruent   f
# 228 171   lettuceSmall     oliveLarge      -363 0; 363 0 incongruent f
# 229  27   tigerSmall       rabbitLarge     -306 0; 306 0 incongruent f
# 230 222   houseLarge       leafSmall       -337 0; 337 0 incongruent j
# 231  81   lizardSmall      rhinoLarge      -369 0; 369 0 congruent   f
# 232  37   butterflySmall   elephantLarge   -322 0; 322 0 congruent   f
# 233 223   treeSmall        lighterLarge    -192 0; 192 0 incongruent f
# 234  36   elephantLarge    butterflySmall  -322 0; 322 0 congruent   j
# 235  31   gorillaSmall     squirrelLarge   -306 0; 306 0 incongruent f
# 236 199   schoolbusSmall   bikeLarge       -366 0; 366 0 incongruent f
# 237 151   orangeSmall      raspberryLarge  -308 0; 308 0 incongruent f
# 238 196   helicopterLarge  tricycleSmall   -353 0; 353 0 congruent   j
# 239 101   scissorsSmall    trunkLarge      -215 0; 215 0 congruent   f
# 240 173   oliveSmall       lettuceLarge    -365 0; 365 0 congruent   f
#     RT   trial_number subject_id correct_side correct_key correct trial_block
# 1    729  70          1          right        j           1       2
# 2    625   5          1          left         f           1       2
# 3   1477  80          1          right        j           1       2
# 4    793  32          1          right        j           1       2
# 5    900 110          1          right        j           1       1
# 6    699  95          1          left         f           1       2
# 7    752  19          1          left         f           1       2
# 8    567  40          1          right        j           1       2
# 9    556  69          1          left         f           1       2
# 10   801 114          1          right        j           1       1
# 11   564  52          1          right        j           1       2
# 12   597  55          1          left         f           1       2
# 13   534  45          1          left         f           1       2
# 14   436  93          1          left         f           1       1
# 15   457  18          1          right        j           1       2
# 16   481  59          1          left         f           1       1
# 17   480  47          1          left         f           1       2
# 18   426  49          1          left         f           1       1
# 19   437  93          1          left         f           1       2
# 20   606   8          1          right        j           1       2
# 21   460  65          1          left         f           1       1
# 22   454  45          1          left         f           1       1
# 23   614  84          1          right        j           1       2
# 24   490  87          1          left         f           1       1
# 25  1037  83          1          left         f           1       1
# 26   485  51          1          left         f           1       1
# 27   493 116          1          right        j           1       1
# 28   428  77          1          left         f           1       1
# 29   501 109          1          left         f           1       2
# 30   990  91          1          left         f           1       1
# ⋮   ⋮    ⋮            ⋮          ⋮            ⋮           ⋮       ⋮
# 211  808  43          1          left         f           1       1
# 212  957  42          1          right        j           1       1
# 213  540  33          1          left         f           1       1
# 214  404  23          1          left         f           1       2
# 215  586 106          1          right        j           1       2
# 216  560  20          1          right        j           1       1
# 217 1199 130          1          right        j           1       2
# 218  478  11          1          left         f           1       2
# 219 1407  54          1          right        j           1       2
# 220  547 104          1          right        j           1       2
# 221  522 128          1          right        j           1       2
# 222  498  12          1          right        j           1       2
# 223  490  76          1          right        j           1       1
# 224  437   9          1          left         f           1       2
# 225  727 102          1          right        j           1       1
# 226  523 127          1          left         f           1       2
# 227  447  37          1          left         f           1       2
# 228  416  51          1          left         f           1       2
# 229  455  27          1          left         f           1       1
# 230  518 102          1          right        j           1       2
# 231  458  81          1          left         f           1       1
# 232  433  37          1          left         f           1       1
# 233  429 103          1          left         f           1       2
# 234  476  36          1          right        j           1       1
# 235  456  31          1          left         f           1       1
# 236  672  79          1          left         f           1       2
# 237  357  31          1          left         f           1       2
# 238  498  76          1          right        j           1       2
# 239  697 101          1          left         f           1       1
# 240  414  53          1          left         f           1       2

# %% [markdown]
# #### Exercise 9
# It is good practice to use a consistent style throughout your script. One such style is called **snake**, the standard in python, which uses only lowercase letters and underscores: `variable_name`. Another common style is **camel**, the standard in JavaScript, which uses capital letters to mark the beginning of a new word: `variableName`. Our tibble at this point uses both styles, so turn all variable names to snake case. You can use `colnames` to see the vector of column names.

# %%
colnames(data)
# Out:
#  [1] "rowNo"        "stim_left"    "stim_right"   "stimPos"      "trial_type"
#  [6] "response"     "RT"           "trial_number" "subject_id"   "correct_side"
# [11] "correct_key"  "correct"      "trial_block"

# %%
data <- data %>% 
  rename(
    stim_pos = stimPos,
    rt = RT,
    row_no = rowNo
  )

# %%
colnames(data)
# Out:
#  [1] "row_no"       "stim_left"    "stim_right"   "stim_pos"     "trial_type"
#  [6] "response"     "rt"           "trial_number" "subject_id"   "correct_side"
# [11] "correct_key"  "correct"      "trial_block"

# %% [markdown]
# #### Exercise 10
# Using `select`, reorder the columns such that participant information comes first, followed by trial block and number, followed by trial info.

# %%
data <- data %>% 
  select(subject_id, trial_block, trial_number, everything())

# %% [markdown]
# #### Exercise 11
# Concatenate all the commands in Exercises 1–10 into a single cell and store the output in a variable called `tidy_data`.

# %%
data1 <- read_csv("data/148338_220209_095045_M057814.csv", skip=2)


education_level <- data1 %>% pull(response) %>% first()  

data1 <- data1 %>%
    # Keep only useful columns
    select(c(rowNo, type, stim1, stim2, stimPos, trialType, response, RT)) %>%
    
    # Keep only useful rows
    filter(type != "form") %>%
    
    # Add demographic and trial-number info, turn trial type to factor
    mutate(
        education_level = education_level, # Add info
        trial_number = row_number(),
        trialType = factor(trialType, levels = c("incongruent", "congruent"))
    ) %>%
    
    # Rename trialType to trial_type
    rename(trial_type = trialType)

head(data1)

tidy_data <- data1 %>%
  select(-type, -education_level) %>% 
  rename(stim_left = stim1, stim_right = stim2) %>%
  mutate(
    subject_id = 1,
    correct_side = if_else(str_detect(stim_left, "Small"), "left", "right"),
    correct_key = if_else(correct_side == "left", "f", "j"),
    correct = if_else(response == correct_key, 1, 0),
    trial_block = if_else(rowNo <= 120, 1, 2),
    trial_number = if_else(rowNo > 120, rowNo - 120, rowNo)
  ) %>%
  rename(
    stim_pos = stimPos,
    rt = RT,
    row_no = rowNo
  ) %>%
  select(subject_id, trial_block, trial_number, everything())
# Out:
# Rows: 241 Columns: 32
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (21): type, stim1, stim2, stimPos, stimFormat, feedbackIncorrect, head, ...
# dbl (11): rowNo, ITI, feedbackTime, random, ITI_ms, ITI_f, ITI_fDuration, ti...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   rowNo type stim1          stim2          stimPos       trial_type  response
# 1 190   test croissantLarge breadSmall     -341 0; 341 0 incongruent j
# 2 125   test lampSmall      shelfLarge     -235 0; 235 0 congruent   f
# 3 200   test schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j
# 4 152   test orangeLarge    raspberrySmall -307 0; 307 0 congruent   j
# 5 110   test hammerLarge    ladderSmall    -156 0; 156 0 incongruent j
# 6 215   test wheelSmall     coinLarge      -300 0; 300 0 incongruent f
#   RT   education_level             trial_number
# 1  729 College or Technical School 1
# 2  625 College or Technical School 2
# 3 1477 College or Technical School 3
# 4  793 College or Technical School 4
# 5  900 College or Technical School 5
# 6  699 College or Technical School 6

# %% [markdown]
# ### Summary statistics

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct))
# Out:
#   rt       accuracy  error
# 1 622.7542 0.9833333 0.01666667

# %%
tidy_data %>%
    mutate(avg_error = mean(1 - correct))
# Out:
#     subject_id trial_block trial_number row_no stim_left        stim_right
# 1   1          2            70          190    croissantLarge   breadSmall
# 2   1          2             5          125    lampSmall        shelfLarge
# 3   1          2            80          200    schoolbusLarge   bikeSmall
# 4   1          2            32          152    orangeLarge      raspberrySmall
# 5   1          1           110          110    hammerLarge      ladderSmall
# 6   1          2            95          215    wheelSmall       coinLarge
# 7   1          2            19          139    coconutSmall     blueberryLarge
# 8   1          2            40          160    pumpkinLarge     mushroomSmall
# 9   1          2            69          189    croissantSmall   breadLarge
# 10  1          1           114          114    trayLarge        bedSmall
# 11  1          2            52          172    lettuceLarge     oliveSmall
# 12  1          2            55          175    cornSmall        green beanLarge
# 13  1          2            45          165    chilliSmall      eggplantLarge
# 14  1          1            93           93    kittySmall       donkeyLarge
# 15  1          2            18          138    apricotLarge     watermelonSmall
# 16  1          1            59           59    cowSmall         hedgehogLarge
# 17  1          2            47          167    cauliflowerSmall onionLarge
# 18  1          1            49           49    duckSmall        zebraLarge
# 19  1          2            93          213    wheelbarrowSmall carLarge
# 20  1          2             8          128    dishwasherLarge  backpackSmall
# 21  1          1            65           65    chickenSmall     pandaLarge
# 22  1          1            45           45    parrotSmall      orangutanLarge
# 23  1          2            84          204    airplaneLarge    skateboardSmall
# 24  1          1            87           87    deerSmall        frogLarge
# 25  1          1            83           83    giraffeSmall     antLarge
# 26  1          1            51           51    dolphinSmall     goldfishLarge
# 27  1          1           116          116    tableLarge       hairdryerSmall
# 28  1          1            77           77    beeSmall         sheepLarge
# 29  1          2           109          229    graterSmall      skyscraperLarge
# 30  1          1            91           91    donkeySmall      kittyLarge
# ⋮   ⋮          ⋮           ⋮            ⋮      ⋮                ⋮
# 211 1          1            43           43    orangutanSmall   parrotLarge
# 212 1          1            42           42    pigeonLarge      camelSmall
# 213 1          1            33           33    squirrelSmall    gorillaLarge
# 214 1          2            23          143    pineappleSmall   cherryLarge
# 215 1          2           106          226    lighterLarge     treeSmall
# 216 1          1            20           20    alligatorLarge   shrimpSmall
# 217 1          2           130          250    beltLarge        cannonSmall
# 218 1          2            11          131    ovenSmall        bootLarge
# 219 1          2            54          174    oliveLarge       lettuceSmall
# 220 1          2           104          224    treeLarge        lighterSmall
# 221 1          2           128          248    cannonLarge      beltSmall
# 222 1          2            12          132    ovenLarge        bootSmall
# 223 1          1            76           76    sheepLarge       beeSmall
# 224 1          2             9          129    backpackSmall    dishwasherLarge
# 225 1          1           102          102    scissorsLarge    trunkSmall
# 226 1          2           127          247    cannonSmall      beltLarge
# 227 1          2            37          157    plumSmall        melonLarge
# 228 1          2            51          171    lettuceSmall     oliveLarge
# 229 1          1            27           27    tigerSmall       rabbitLarge
# 230 1          2           102          222    houseLarge       leafSmall
# 231 1          1            81           81    lizardSmall      rhinoLarge
# 232 1          1            37           37    butterflySmall   elephantLarge
# 233 1          2           103          223    treeSmall        lighterLarge
# 234 1          1            36           36    elephantLarge    butterflySmall
# 235 1          1            31           31    gorillaSmall     squirrelLarge
# 236 1          2            79          199    schoolbusSmall   bikeLarge
# 237 1          2            31          151    orangeSmall      raspberryLarge
# 238 1          2            76          196    helicopterLarge  tricycleSmall
# 239 1          1           101          101    scissorsSmall    trunkLarge
# 240 1          2            53          173    oliveSmall       lettuceLarge
#     stim_pos      trial_type  response rt   correct_side correct_key correct
# 1   -341 0; 341 0 incongruent j         729 right        j           1
# 2   -235 0; 235 0 congruent   f         625 left         f           1
# 3   -370 0; 370 0 congruent   j        1477 right        j           1
# 4   -307 0; 307 0 congruent   j         793 right        j           1
# 5   -156 0; 156 0 incongruent j         900 right        j           1
# 6   -300 0; 300 0 incongruent f         699 left         f           1
# 7   -309 0; 309 0 incongruent f         752 left         f           1
# 8   -304 0; 304 0 congruent   j         567 right        j           1
# 9   -341 0; 341 0 congruent   f         556 left         f           1
# 10  -350 0; 350 0 incongruent j         801 right        j           1
# 11  -365 0; 365 0 congruent   j         564 right        j           1
# 12  -349 0; 349 0 incongruent f         597 left         f           1
# 13  -274 0; 274 0 congruent   f         534 left         f           1
# 14  -309 0; 309 0 congruent   f         436 left         f           1
# 15  -300 0; 300 0 incongruent j         457 right        j           1
# 16  -358 0; 358 0 incongruent f         481 left         f           1
# 17  -321 0; 321 0 incongruent f         480 left         f           1
# 18  -311 0; 311 0 congruent   f         426 left         f           1
# 19  -347 0; 347 0 congruent   f         437 left         f           1
# 20  -259 0; 259 0 congruent   j         606 right        j           1
# 21  -333 0; 333 0 congruent   f         460 left         f           1
# 22  -207 0; 207 0 congruent   f         454 left         f           1
# 23  -334 0; 334 0 congruent   j         614 right        j           1
# 24  -299 0; 299 0 incongruent f         490 left         f           1
# 25  -324 0; 324 0 incongruent f        1037 left         f           1
# 26  -341 0; 341 0 incongruent f         485 left         f           1
# 27  -350 0; 350 0 congruent   j         493 right        j           1
# 28  -321 0; 321 0 congruent   f         428 left         f           1
# 29  -220 0; 220 0 congruent   f         501 left         f           1
# 30  -317 0; 317 0 incongruent f         990 left         f           1
# ⋮   ⋮             ⋮           ⋮        ⋮    ⋮            ⋮           ⋮
# 211 -198 0; 198 0 incongruent f         808 left         f           1
# 212 -250 0; 250 0 incongruent j         957 right        j           1
# 213 -306 0; 306 0 congruent   f         540 left         f           1
# 214 -223 0; 223 0 incongruent f         404 left         f           1
# 215 -192 0; 192 0 incongruent j         586 right        j           1
# 216 -337 0; 337 0 congruent   j         560 right        j           1
# 217 -353 0; 353 0 incongruent j        1199 right        j           1
# 218 -280 0; 280 0 incongruent f         478 left         f           1
# 219 -363 0; 363 0 incongruent j        1407 right        j           1
# 220 -208 0; 208 0 congruent   j         547 right        j           1
# 221 -353 0; 353 0 congruent   j         522 right        j           1
# 222 -273 0; 273 0 congruent   j         498 right        j           1
# 223 -321 0; 321 0 congruent   j         490 right        j           1
# 224 -259 0; 259 0 congruent   f         437 left         f           1
# 225 -198 0; 198 0 incongruent j         727 right        j           1
# 226 -353 0; 353 0 incongruent f         523 left         f           1
# 227 -330 0; 330 0 congruent   f         447 left         f           1
# 228 -363 0; 363 0 incongruent f         416 left         f           1
# 229 -306 0; 306 0 incongruent f         455 left         f           1
# 230 -337 0; 337 0 incongruent j         518 right        j           1
# 231 -369 0; 369 0 congruent   f         458 left         f           1
# 232 -322 0; 322 0 congruent   f         433 left         f           1
# 233 -192 0; 192 0 incongruent f         429 left         f           1
# 234 -322 0; 322 0 congruent   j         476 right        j           1
# 235 -306 0; 306 0 incongruent f         456 left         f           1
# 236 -366 0; 366 0 incongruent f         672 left         f           1
# 237 -308 0; 308 0 incongruent f         357 left         f           1
# 238 -353 0; 353 0 congruent   j         498 right        j           1
# 239 -215 0; 215 0 congruent   f         697 left         f           1
# 240 -365 0; 365 0 congruent   f         414 left         f           1
#     avg_error
# 1   0.01666667
# 2   0.01666667
# 3   0.01666667
# 4   0.01666667
# 5   0.01666667
# 6   0.01666667
# 7   0.01666667
# 8   0.01666667
# 9   0.01666667
# 10  0.01666667
# 11  0.01666667
# 12  0.01666667
# 13  0.01666667
# 14  0.01666667
# 15  0.01666667
# 16  0.01666667
# 17  0.01666667
# 18  0.01666667
# 19  0.01666667
# 20  0.01666667
# 21  0.01666667
# 22  0.01666667
# 23  0.01666667
# 24  0.01666667
# 25  0.01666667
# 26  0.01666667
# 27  0.01666667
# 28  0.01666667
# 29  0.01666667
# 30  0.01666667
# ⋮   ⋮
# 211 0.01666667
# 212 0.01666667
# 213 0.01666667
# 214 0.01666667
# 215 0.01666667
# 216 0.01666667
# 217 0.01666667
# 218 0.01666667
# 219 0.01666667
# 220 0.01666667
# 221 0.01666667
# 222 0.01666667
# 223 0.01666667
# 224 0.01666667
# 225 0.01666667
# 226 0.01666667
# 227 0.01666667
# 228 0.01666667
# 229 0.01666667
# 230 0.01666667
# 231 0.01666667
# 232 0.01666667
# 233 0.01666667
# 234 0.01666667
# 235 0.01666667
# 236 0.01666667
# 237 0.01666667
# 238 0.01666667
# 239 0.01666667
# 240 0.01666667

# %% [markdown]
# #### Exercise 12
# Using the `.by` argument in the call to `summarize`, find out if our participant showed the predicted size Stroop in reaction times and error rates.

# %%
tidy_data %>% 
  summarize(
    mean_rt = mean(rt), 
    error_rate = 1 - mean(correct), 
    .by = trial_type
  )
# Out:
#   trial_type  mean_rt  error_rate
# 1 incongruent 698.1000 0.03333333
# 2 congruent   547.4083 0.00000000

# %% [markdown]
# #### Exercise 13
# Using a similar logic, find out if our participant also showed a SNARC effect: Was the participant faster when the small image was on the left?

# %%
tidy_data %>% 
  summarize(
    mean_rt = mean(rt), 
    .by = correct_side
  )
# Out:
#   correct_side mean_rt
# 1 right        632.7333
# 2 left         612.7750

# %% [markdown]
# #### Exercise 14
# Find out if the SNARC effect depends on trial type.

# %%
tidy_data %>% 
  summarize(
    mean_rt = mean(rt), 
    .by = c(trial_type, correct_side)
  )
# Out:
#   trial_type  correct_side mean_rt
# 1 incongruent right        694.9167
# 2 congruent   left         524.2667
# 3 congruent   right        570.5500
# 4 incongruent left         701.2833

# %% [markdown]
# ## From a single participant to a full dataset
# We load all the 12 csv files in the 'data' folder, then apply the `read_csv` function to each of them using `map_dfr`. The `.id` argument creates a column that keeps the information from each file separate. This is equivalent to having a subject_id, if there is one .csv file per participant.

# %%
# Fetch all the files in the 'data' folder that end in .csv
raw_data <- list.files(path = 'data', pattern = ".csv$", full.names = TRUE) %>% 

  # Map the read_csv function to all of them, skipping the first 2 rows and creating a new id column called 'id' so that each file gets its own id
  # col_types = cols() just makes explicit that you want tidyverse to do its best to guess the type of each column (string, numeric, etc.)
  map_dfr(read_csv, col_types = cols(), skip = 2, .id = 'id')

# %% [markdown]
# #### Exercise 15
# Tidy the dataset exactly as we did for subject 1, while keeping the education-level information for each subject. Store it as `tidy_data`.
#
# Hint: **group** the tibble before calling `first(response)`), then follow the same steps as before to obtain a tidy dataset. Use `ungroup()` to return to the tibble to the ungrouped state. In fact, in most of the exercises that follow, you will need to use grouping wisely.
#
# ```R
# full_data <- raw_data %>%
#     mutate(education_level = first(response), .by = id) %>%
#     ...
# ```

# %%
tidy_data <- raw_data %>%

  mutate(education_level = first(response), .by = id) %>%
  
  
  rename(stim_left = stim1, stim_right = stim2) %>%
  
  mutate(
    correct_side = if_else(str_detect(stim_left, "Small"), "left", "right"),
    correct_key = if_else(correct_side == "left", "f", "j"),
    correct = if_else(response == correct_key, 1, 0),
    
    trial_block = if_else(rowNo <= 120, 1, 2),
    trial_number = if_else(rowNo > 120, rowNo - 120, rowNo)
  ) %>%
  rename(
    stim_pos = stimPos,
    rt = RT,
    row_no = rowNo
  ) %>%
  
  select(id, education_level, trial_block, trial_number, everything())

# %%
head(tidy_data)
# Out:
#   id education_level             trial_block trial_number row_no type
# 1 1  College or Technical School 1             2            2    form
# 2 1  College or Technical School 2            70          190    test
# 3 1  College or Technical School 2             5          125    test
# 4 1  College or Technical School 2            80          200    test
# 5 1  College or Technical School 2            32          152    test
# 6 1  College or Technical School 1           110          110    test
#   stim_left      stim_right     stim_pos      ITI ⋯ ITI_ms ITI_f ITI_fDuration
# 1 NA             NA             NA             NA ⋯  NA    NA       NA
# 2 croissantLarge breadSmall     -341 0; 341 0 700 ⋯ 700    42    16.67
# 3 lampSmall      shelfLarge     -235 0; 235 0 700 ⋯ 700    42    16.67
# 4 schoolbusLarge bikeSmall      -370 0; 370 0 700 ⋯ 700    42    16.67
# 5 orangeLarge    raspberrySmall -307 0; 307 0 700 ⋯ 700    42    16.66
# 6 hammerLarge    ladderSmall    -156 0; 156 0 700 ⋯ 700    42    16.66
#   timestamp response                    rt   correct responseCode correct_side
# 1 24595     College or Technical School 3563 NA       3           NA
# 2 63999     j                            729  1      NA           right
# 3 65310     f                            625  1      NA           left
# 4 67480     j                           1477  1      NA           right
# 5 68963     j                            793  1      NA           right
# 6 70553     j                            900  1      NA           right
#   correct_key
# 1 NA
# 2 j
# 3 f
# 4 j
# 5 j
# 6 j

# %% [markdown]
# #### Exercise 16
# Trials where the responses were too slow or too fast should be excluded from the analysis. (Why?)
# Exclude the trials where the response is below 200 ms or higher than 1,500 ms. How many trials were excluded?

# %%
n_total <- nrow(tidy_data)


clean_data <- tidy_data %>% 
  filter(rt >= 200 & rt <= 1500)

n_excluded <- n_total - nrow(clean_data)
print(n_excluded)
# Out:
# [1] 296

# %% [markdown]
# #### Exercise 17
# Exclude participants who didn't achieve 93% overall accuracy.
# How many subjects were excluded?

# %%
valid_subjects <- clean_data %>%
  summarize(acc = mean(correct), .by = id) %>%
  filter(acc >= 0.93) %>%
  pull(id)
final_data <- clean_data %>%
  filter(id %in% valid_subjects)

print(n_distinct(clean_data$id) - n_distinct(final_data$id))
# Out:
# [1] 1

# %% [markdown]
# #### Exercise 18
# Summarize the response-time and accuracy measures by trial type to check whether there's a Stroop effect.

# %%
final_data %>%
  summarize(
    mean_rt = mean(rt),
    mean_acc = mean(correct),
    .by = trialType
  )
# Out:
#   trialType   mean_rt  mean_acc
# 1 incongruent 814.4211 0.935289
# 2 congruent   707.7510 0.994152

# %% [markdown]
# ## Changing the format of the data: `pivot_wider`, `pivot_longer`

# %% [markdown]
# #### Exercise 19: `pivot_wider`
# Compute the average Stroop effects for each participant. One column should be called `stroop_rt`, the other should be called `stroop_error`. Using `pull`, extract the reaction-time Stroop vector and plot its histogram.

# %%
subject_means <- final_data %>%
  summarize(
    mean_rt = mean(rt),
    mean_err = 1 - mean(correct),
    .by = c(id, trialType)
  ) %>%
  pivot_wider(
    names_from = trialType, 
    values_from = c(mean_rt, mean_err)
  ) %>%
  mutate(
    stroop_rt = mean_rt_incongruent - mean_rt_congruent,
    stroop_error = mean_err_incongruent - mean_err_congruent
  )

stroop_rt_vec <- subject_means %>% pull(stroop_rt)
hist(stroop_rt_vec)
# Out:
# Plot with title “Histogram of stroop_rt_vec”

# %% [markdown]
# #### Exercise 20: `pivot_longer`
# Building on the output tibble in Exercise 19, remove all columns except `id`, `stroop_rt`, and `stroop_error`, then gather the two stroop columns into a single column called `measure`. This column should take one of two values for each subject (`stroop_rt` or `stroop_error`), while the `value` column should register the respective participants' stroop effect.

# %%
stroop_long <- subject_means %>%
  select(id, stroop_rt, stroop_error) %>%
  pivot_longer(
    cols = c(stroop_rt, stroop_error),
    names_to = "measure",
    values_to = "value"
  )

head(stroop_long)
# Out:
#   id measure      value
# 1 1  stroop_rt    136.54929379
# 2 1  stroop_error   0.03389831
# 3 2  stroop_rt     15.50925926
# 4 2  stroop_error   0.06481481
# 5 3  stroop_rt    126.06837607
# 6 3  stroop_error   0.08547009

# %% [markdown]
# ## Data plotting

# %% [markdown]
# ### Rule 1: If your data is in the tidy format (one variable per column, one observation per row), plotting with `ggplot` will be very easy.

# %% [markdown]
# ### Rule 2: No barplots.

# %% [markdown]
# ### One possible way to do it

# %%
average_data <- final_data %>% summarize(rt = mean(rt), .by = c(id, trialType)) 

ggplot(average_data, aes(x = trialType, y = rt, fill = trialType)) +
  geom_boxplot(width = 0.5, alpha = 0.45) +
  geom_point(size = 2) +
  geom_line(aes(group = id), color = 'gray') +         
  stat_summary(fun.data = mean_se, linewidth = 2, shape = 21, size = 1.5) +
  labs(title = "Average reaction times by trial type (ms)", x = "Trial type", y = "") +
  theme_minimal() + 
  theme(
    legend.position = "none", 
    plot.title = element_text(face = "bold", size = 20),
    axis.title = element_text(size = 18),
    axis.text = element_text(size = 16))
# Out:
# plot without title
